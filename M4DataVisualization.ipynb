# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="380" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Data Visualization Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be focusing on the visualization of data.
#
# The data set will be presented to you in the form of a RDBMS.
#
# You will have to use SQL queries to extract the data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Demo: How to work with database

# %% [markdown]
# Download database file.

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Out:
# --2024-08-02 22:15:49--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.45.118.108
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.45.118.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36679680 (35M) [application/octet-stream]
# Saving to: 'm4_survey_data.sqlite.1'
#
#      0K .......... .......... .......... .......... ..........  0%  779K 46s
#     50K .......... .......... .......... .......... ..........  0% 1.20M 37s
#    100K .......... .......... .......... .......... ..........  0% 2.37M 30s
#    150K .......... .......... .......... .......... ..........  0% 2.85M 25s
# ...

# %% [markdown]
# Connect to the database.

# %%
import sqlite3
conn = sqlite3.connect("m4_survey_data.sqlite") # open a database connection
cur = conn.cursor()

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# ## Demo: How to run an sql query

# %%
# print how many rows are there in the table named 'master'
QUERY = """
SELECT COUNT(*)
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    COUNT(*)
# 0     11398

# %% [markdown]
# ## Demo: How to list all tables

# %%
# print all the tables names in the database
QUERY = """
SELECT name as Table_Name FROM
sqlite_master WHERE
type = 'table'
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
pd.read_sql_query(QUERY,conn)
# Out:
#                 Table_Name
# 0                 EduOther
# 1                  DevType
# 2                  LastInt
# 3               JobFactors
# 4                 WorkPlan
# 5            WorkChallenge
# 6       LanguageWorkedWith
# 7   LanguageDesireNextYear
# 8       DatabaseWorkedWith
# 9   DatabaseDesireNextYear
# 10      PlatformWorkedWith
# 11  PlatformDesireNextYear
# 12      WebFrameWorkedWith
# 13  WebFrameDesireNextYear
# 14      MiscTechWorkedWith
# 15  MiscTechDesireNextYear
# 16              DevEnviron
# 17              Containers
# 18               SOVisitTo
# 19            SONewContent
# 20                  Gender
# 21               Sexuality
# 22               Ethnicity
# 23                  master

# %% [markdown]
# ## Demo: How to run a group by query

# %%
QUERY = """
SELECT Age,COUNT(*) as count
FROM master
group by age
order by age
"""
pd.read_sql_query(QUERY,conn)
# Out:
#      Age  count
# 0    NaN    287
# 1   16.0      3
# 2   17.0      6
# 3   18.0     29
# 4   19.0     78
# 5   20.0    109
# 6   21.0    203
# 7   22.0    406
# 8   23.0    581
# 9   24.0    679
# 10  25.0    738
# 11  26.0    720
# 12  27.0    724
# 13  28.0    787
# 14  29.0    697
# 15  30.0    651
# 16  31.0    531
# 17  32.0    489
# 18  33.0    483
# 19  34.0    395
# 20  35.0    393
# 21  36.0    308
# 22  37.0    280
# 23  38.0    279
# 24  39.0    232
# 25  40.0    187
# 26  41.0    136
# 27  42.0    162
# 28  43.0    100
# 29  44.0     95
# 30  45.0     85
# 31  46.0     66
# 32  47.0     68
# 33  48.0     64
# 34  49.0     66
# 35  50.0     57
# 36  51.0     29
# 37  52.0     41
# 38  53.0     32
# 39  54.0     26
# 40  55.0     13
# 41  56.0     16
# 42  57.0     11
# 43  58.0     12
# 44  59.0     11
# 45  60.0      2
# 46  61.0     10
# 47  62.0      5
# 48  63.0      7
# 49  65.0      2
# 50  66.0      1
# 51  67.0      1
# 52  69.0      1
# 53  71.0      2
# ...

# %% [markdown]
# ## Demo: How to describe a table

# %%
table_name = 'master'  # the table you wish to describe

QUERY = """
SELECT sql FROM sqlite_master
WHERE name= '{}'
""".format(table_name)

df = pd.read_sql_query(QUERY,conn)
print(df.iat[0,0])
# Out:
# CREATE TABLE "master" (
# "index" INTEGER,
#   "Respondent" INTEGER,
#   "MainBranch" TEXT,
#   "Hobbyist" TEXT,
#   "OpenSourcer" TEXT,
#   "OpenSource" TEXT,
#   "Employment" TEXT,
#   "Country" TEXT,
#   "Student" TEXT,
#   "EdLevel" TEXT,
#   "UndergradMajor" TEXT,
#   "OrgSize" TEXT,
#   "YearsCode" TEXT,
#   "Age1stCode" TEXT,
#   "YearsCodePro" TEXT,
#   "CareerSat" TEXT,
#   "JobSat" TEXT,
#   "MgrIdiot" TEXT,
#   "MgrMoney" TEXT,
#   "MgrWant" TEXT,
#   "JobSeek" TEXT,
#   "LastHireDate" TEXT,
#   "FizzBuzz" TEXT,
#   "ResumeUpdate" TEXT,
#   "CurrencySymbol" TEXT,
#   "CurrencyDesc" TEXT,
#   "CompTotal" REAL,
#   "CompFreq" TEXT,
#   "ConvertedComp" REAL,
#   "WorkWeekHrs" REAL,
#   "WorkRemote" TEXT,
#   "WorkLoc" TEXT,
#   "ImpSyn" TEXT,
#   "CodeRev" TEXT,
#   "CodeRevHrs" REAL,
#   "UnitTests" TEXT,
#   "PurchaseHow" TEXT,
#   "PurchaseWhat" TEXT,
#   "OpSys" TEXT,
#   "BlockchainOrg" TEXT,
#   "BlockchainIs" TEXT,
#   "BetterLife" TEXT,
#   "ITperson" TEXT,
# ...

# %% [markdown]
# # Hands-on Lab

# %% [markdown]
# ## Visualizing distribution of data

# %% [markdown]
# ### Histograms

# %% [markdown]
# Plot a histogram of `ConvertedComp.`

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
QUERY = """
SELECT ConvertedComp
FROM master
"""
df = pd.read_sql_query(QUERY,conn)
df
# Out:
#        ConvertedComp
# 0            61000.0
# 1            95179.0
# 2            90000.0
# 3           455352.0
# 4            65277.0
# ...              ...
# 11393       130000.0
# 11394        19880.0
# 11395       105000.0
# 11396        80371.0
# 11397            NaN
#
# [11398 rows x 1 columns]

# %%
sns.displot(df, height = 7, aspect =1)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Box Plots

# %% [markdown]
# Plot a box plot of `Age.`

# %%
QUERY = """
SELECT Age
FROM master
"""
df = pd.read_sql_query(QUERY,conn)
df
sns.boxplot(df)
# Out:
# <Axes: >

# %% [markdown]
# ## Visualizing relationships in data

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Create a scatter plot of `Age` and `WorkWeekHrs.`

# %%
QUERY = """
SELECT Age, WorkWeekHrs
FROM master
"""
df = pd.read_sql_query(QUERY,conn)
df
# Out:
#         Age  WorkWeekHrs
# 0      22.0         80.0
# 1      23.0         32.0
# 2      28.0         40.0
# 3      26.0         40.0
# 4      29.0         45.0
# ...     ...          ...
# 11393  36.0         40.0
# 11394  25.0         40.0
# 11395  34.0         40.0
# 11396  25.0         42.5
# 11397  30.0         80.0
#
# [11398 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data = df, x = 'Age', y = 'WorkWeekHrs', color='darkblue')
plt.title('Age_WorkWeekHrs Relationship')
plt.ylabel('WorkWeekHrs')
plt.xlabel('Age')

plt.show()

# %% [markdown]
# ### Bubble Plots

# %% [markdown]
# Create a bubble plot of `WorkWeekHrs` and `CodeRevHrs`, use `Age` column as bubble size.

# %%
QUERY = """
SELECT Age, WorkWeekHrs, CodeRevHrs
FROM master

"""
df = pd.read_sql_query(QUERY,conn)
df
# Out:
#         Age  WorkWeekHrs  CodeRevHrs
# 0      22.0         80.0         NaN
# 1      23.0         32.0        12.0
# 2      28.0         40.0         5.0
# 3      26.0         40.0         NaN
# 4      29.0         45.0         5.0
# ...     ...          ...         ...
# 11393  36.0         40.0         NaN
# 11394  25.0         40.0         5.0
# 11395  34.0         40.0         5.0
# 11396  25.0         42.5         2.0
# 11397  30.0         80.0         1.0
#
# [11398 rows x 3 columns]

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(data = df, y = 'WorkWeekHrs', x = 'CodeRevHrs', size = 'Age', alpha = 0.9, sizes=(20, 200), color='darkblue')
plt.show()

# %% [markdown]
# ## Visualizing composition of data

# %% [markdown]
# ### Pie Charts

# %% [markdown]
# Create a pie chart of the top 5 databases that respondents wish to learn next year. Label the pie chart with database names. Display percentages of each database on the pie chart.

# %%
QUERY = """
SELECT  count(*) as count ,DevType
FROM DevType
group by DevType
order by count desc

"""
df = pd.read_sql_query(QUERY,conn)
df
# Out:
#     count                                        DevType
# 0    6928                          Developer, full-stack
# 1    6290                            Developer, back-end
# 2    3920                           Developer, front-end
# 3    2575  Developer, desktop or enterprise applications
# 4    1959                              Developer, mobile
# 5    1639                              DevOps specialist
# 6    1413                         Database administrator
# 7    1202                           System administrator
# 8     988                                       Designer
# 9     911                          Developer, QA or test
# 10    854    Developer, embedded applications or devices
# 11    832                                 Engineer, data
# 12    803  Data scientist or machine learning specialist
# 13    802                       Data or business analyst
# 14    766                                        Student
# ...

# %%
QUERY = """
SELECT *
FROM sqlite_master

"""
df = pd.read_sql_query(QUERY,conn)
df
# Out:
#      type                    name                tbl_name  rootpage  \
# 0   table                EduOther                EduOther         2
# 1   table                 DevType                 DevType       741
# 2   table                 LastInt                 LastInt      1024
# 3   table              JobFactors              JobFactors      1355
# 4   table                WorkPlan                WorkPlan      1808
# 5   table           WorkChallenge           WorkChallenge      2088
# 6   table      LanguageWorkedWith      LanguageWorkedWith      2378
# 7   table  LanguageDesireNextYear  LanguageDesireNextYear      2638
# 8   table      DatabaseWorkedWith      DatabaseWorkedWith      2877
# 9   table  DatabaseDesireNextYear  DatabaseDesireNextYear      3028
# 10  table      PlatformWorkedWith      PlatformWorkedWith      3170
# 11  table  PlatformDesireNextYear  PlatformDesireNextYear      3341
# 12  table      WebFrameWorkedWith      WebFrameWorkedWith      3540
# ...

# %%
QUERY = """
SELECT *
FROM LanguageDesireNextYear

"""
df = pd.read_sql_query(QUERY,conn)
df
# Out:
#        Respondent LanguageDesireNextYear
# 0               4                      C
# 1               4                     C#
# 2               4             JavaScript
# 3               4                    SQL
# 4               9  Bash/Shell/PowerShell
# ...           ...                    ...
# 55759       25142  Bash/Shell/PowerShell
# 55760       25142                      C
# 55761       25142                    C++
# 55762       25142                 Python
# 55763       25142                      R
#
# [55764 rows x 2 columns]

# %%
QUERY = """
SELECT *
FROM LanguageWorkedWith
where LanguageWorkedWith = 'MySQL'

"""
df = pd.read_sql_query(QUERY,conn)
df
# Out:
# Empty DataFrame
# Columns: [Respondent, LanguageWorkedWith]
# Index: []

# %%
QUERY = """
SELECT count(LanguageDesireNextYear) as Count, LanguageDesireNextYear
FROM LanguageDesireNextYear
group by LanguageDesireNextYear
order by count desc
Limit 5
"""
df = pd.read_sql_query(QUERY,conn)
df
# Out:
#    Count LanguageDesireNextYear
# 0   6630             JavaScript
# 1   5328               HTML/CSS
# 2   5239                 Python
# 3   5012                    SQL
# 4   4088             TypeScript

# %%
data = df['Count']
labels = df['LanguageDesireNextYear']

plt.figure(figsize=(10, 8))
plt.pie(data, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Language names')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
QUERY = """
SELECT *
FROM DatabaseDesireNextYear

"""
df = pd.read_sql_query(QUERY,conn)
df
# Out:
#        Respondent DatabaseDesireNextYear
# 0               4                  MySQL
# 1               4                 SQLite
# 2               9             PostgreSQL
# 3               9                  Redis
# 4               9                 SQLite
# ...           ...                    ...
# 29570       25141          Elasticsearch
# 29571       25141                MongoDB
# 29572       25141   Microsoft SQL Server
# 29573       25141                  Redis
# 29574       25142             PostgreSQL
#
# [29575 rows x 2 columns]

# %%
QUERY = """
SELECT count(DatabaseDesireNextYear) as Count, DatabaseDesireNextYear
FROM DatabaseDesireNextYear
group by DatabaseDesireNextYear
order by count desc
Limit 5
"""
df = pd.read_sql_query(QUERY,conn)
df
# Out:
#    Count DatabaseDesireNextYear
# 0   4328             PostgreSQL
# 1   3649                MongoDB
# 2   3331                  Redis
# 3   3281                  MySQL
# 4   2856          Elasticsearch

# %%
data = df['Count']
labels = df['DatabaseDesireNextYear']

plt.figure(figsize=(10, 8))
plt.pie(data, labels=labels, autopct='%1.0f%%', startangle=90)
plt.title('Database names')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# ### Stacked Charts

# %% [markdown]
# Create a stacked chart of median `WorkWeekHrs` and `CodeRevHrs` for the age group 30 to 35.

# %%
QUERY = """
WITH cte AS (
    SELECT Age, WorkWeekHrs, CodeRevHrs
    FROM master
    WHERE Age BETWEEN 30 AND 35
)
SELECT WorkWeekHrs, CodeRevHrs
FROM cte;

"""
df = pd.read_sql_query(QUERY,conn)
df
# Out:
#       WorkWeekHrs  CodeRevHrs
# 0             8.0         3.0
# 1            40.0         2.0
# 2            40.0         2.0
# 3            42.0        15.0
# 4            40.0         2.0
# ...           ...         ...
# 2937         42.0         4.0
# 2938         50.0         2.0
# 2939         56.0        14.0
# 2940         40.0         5.0
# 2941         80.0         1.0
#
# [2942 rows x 2 columns]

# %%
# Assuming 'conn' is your database connection object
QUERY = """
WITH cte AS (
    SELECT Age, WorkWeekHrs, CodeRevHrs
    FROM master
    WHERE Age BETWEEN 30 AND 35
)
SELECT WorkWeekHrs, CodeRevHrs
FROM cte;
"""

df = pd.read_sql_query(QUERY, conn)

# Calculate median values
median_workweekhrs = df['WorkWeekHrs'].median()
median_coderevhrs = df['CodeRevHrs'].median()

# Data for plotting
median_data = pd.DataFrame({
    'WorkWeekHrs': [median_workweekhrs],
    'CodeRevHrs': [median_coderevhrs]
})

# Plotting the stacked bar chart
median_data.plot(kind='bar', stacked=True, figsize=(10, 6), color=['skyblue', 'lightgreen'])
plt.title('Median WorkWeekHrs and CodeRevHrs')
plt.ylabel('Median Hours')
plt.xticks([0], ['Age 30 - 35'], rotation=0)  # To show a single category name 'Median' on the x-axis
plt.legend(['WorkWeekHrs', 'CodeRevHrs'])
plt.show()

# %% [markdown]
# ## Visualizing comparison of data

# %% [markdown]
# ### Line Chart

# %%
QUERY = """
SELECT Age, ConvertedComp
FROM master
WHERE Age BETWEEN 45 AND 60
"""
df = pd.read_sql_query(QUERY, conn)

# Calculate the median ConvertedComp for each age
medians = df.groupby('Age')['ConvertedComp'].median().reset_index()

# Rename columns for clarity
medians.columns = ['Age', 'MedConvertedComp']

# Plotting the line chart
plt.figure(figsize=(10, 6))
plt.plot(medians['Age'], medians['MedConvertedComp'], color='skyblue', marker='o', linestyle='-')
plt.title('Median ConvertedComp vs Age (45-60)')
plt.ylabel('Median ConvertedComp')
plt.xlabel('Age')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# Create a horizontal bar chart using column `MainBranch.`

# %%
QUERY = "SELECT MainBranch FROM master"
df = pd.read_sql_query(QUERY, conn)

# Count occurrences of each value in the MainBranch column
mainbranch_counts = df['MainBranch'].value_counts()

# Plotting the horizontal bar chart
plt.figure(figsize=(10, 6))
mainbranch_counts.plot(kind='barh', color=['skyblue', 'lightgreen'])
plt.title('Count of MainBranch Categories')
plt.xlabel('Count')
plt.ylabel('MainBranch')
plt.grid(axis='x')
plt.show()

# %% [markdown]
# Close the database connection.

# %%
conn.close()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).

# %% [markdown]
# <!--## Change Log

# %% [markdown]
# <!--| Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |--!>
